# %% [markdown]
# <img src="./caps/utn.jpg" align="right" width="150" />
# #### Teoría de los Circuitos II - 2021
#
# # Tarea semanal 4 - Correción
#
# #### Lauría Juan

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.b)</b> Eliminabanda pasivo.
# </div></div>

# %% [markdown]
# <img src="./caps/cor1.jpg" align="center" width="800" />

# %% [markdown]
# <img src="./caps/cor2.jpg" align="center" width="1000" />

# %%
from splane import pzmap, grpDelay, bodePlot
from scipy.signal import TransferFunction,bode
import matplotlib.pyplot as plt
import numpy as npy

## Simulación matemática.
C1 = 1
C2 = 1
L1 = 1
L2 = 1
R1 = npy.sqrt(2)
R2 = 1/npy.sqrt(2)

K = L2 / L1

a = [K*1,K*R2/L2,K*1/(C2*L2)]
b = [1,R1/L1,1/(C1*L1)]

my_tf = TransferFunction(a,b)

## Ploteo.
bodePlot(my_tf)
pzmap(my_tf)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Implementación activa pasabanda.
# </div></div>

# %% [markdown]
# <img src="./caps/cor3.jpg" align="center" width="800" />

# %% [markdown]
# <img src="./caps/cor4.jpg" align="center" width="1000" />

# %%
from splane import pzmap, grpDelay, bodePlot
from scipy.signal import TransferFunction,bode
import matplotlib.pyplot as plt
import numpy as npy

## Simulación matemática.
R = 1.5
C = 1
L = 0.25


num = [R/L,0]
den = [1,R/L,1/(L*C)]
 
my_tf = TransferFunction( num, den )

## Ploteo.
bodePlot(my_tf)
pzmap(my_tf)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)
