# %% [markdown]
# <img src="./logoutn.jpg" align="right" width="150" />
# ### Teoría de los Circuitos II - 2021
#
# # Tarea semanal 13
# ## Simulación analítica y circuital.
# #### LAURIA JUAN

# %%
from scipy import signal
from splane import pzmap, grpDelay, bodePlot
from scipy.signal import TransferFunction,bode
import matplotlib.pyplot as plt
import numpy as npy

# %% [markdown]
# ## EJERCICIO #1

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Simulación matemática.
# </div></div>

# %% [markdown]
# $ \large\ Y11 = \frac{I2}{I1} = \frac{S^2 + 5S + 4}{S^2 + 8S + 12}$

# %%
#I2/I1
a = [1,5,4]
b = [1,8,12]
my_tf = TransferFunction(a,b)
bodePlot(my_tf)
# Out:
# (1,
#  array([<AxesSubplot:title={'center':'Magnitude response'}, ylabel='Magnitude [dB]'>,
#         <AxesSubplot:title={'center':'Phase response'}, xlabel='Angular frequency [rad/sec]', ylabel='Phase [deg]'>],
#        dtype=object))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Simulación circuital.
# </div></div>

# %% [markdown]
# <img src="./caps/circ1.jpg" align="center" width="4000" />

# %% [markdown]
# <img src="./caps/sim1.jpg" align="center" width="4000" />

# %% [markdown]
# ## EJERCICIO #2

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Simulación matemática.
# </div></div>

# %% [markdown]
# $ \large\ Y11 = \frac{V2}{I1} = \frac{S^2 + 9}{S^3 + 2S^2 + 2S + 1}$

# %%
# V2/I1
a = [1,0,9]
b = [1,2,2,1]
my_tf = TransferFunction(a,b)
bodePlot(my_tf)
# Out:
# (1,
#  array([<AxesSubplot:title={'center':'Magnitude response'}, ylabel='Magnitude [dB]'>,
#         <AxesSubplot:title={'center':'Phase response'}, xlabel='Angular frequency [rad/sec]', ylabel='Phase [deg]'>],
#        dtype=object))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Simulación circuital con Z11.
# </div></div>

# %% [markdown]
# <img src="./caps/circ2.jpg" align="center" width="4000" />

# %% [markdown]
# <img src="./caps/sim2.jpg" align="center" width="4000" />
