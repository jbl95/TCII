# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
# #### Teoría de los Circuitos II - 2021
#
# # Trabajo semanal #3 - Entrega: 20/05/21
# #### Nombre y Apellido: Juan Lauría

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Filtro de 3er orden usando OTA's.
# </div></div>

# %% [markdown]
# Circuito.

# %% [markdown]
# <img src="./caps/circuito.jpg" align="center" width="800" />

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Simulación matemática utilizando la normalización en frecuencia e impedancia.
# </div></div>

# %%
from splane import pzmap, grpDelay, bodePlot
from scipy.signal import TransferFunction,bode
import matplotlib.pyplot as plt
import numpy as npy

## Simulación matemática.

C1 = 0.01
C2 = 0.1
C3 = 1
R3 = 1
G3 = 1 / R3
gm1 = 0.01
gm2 = 0.1
gm3 = 1

c = (gm2 / C2) + (G3 / C3)
b = ((gm1*gm2) / (C1*C2)) + ((gm2*G3) / (C2*C3))
a = ((gm1*gm2*G3) / (C1*C2*C3))
d = ((gm1*gm2*gm3) / (C1*C2*C3))

num = [d]
den = [1,c,b,a]
 
my_tf = TransferFunction( num, den )

## Ploteo.
bodePlot(my_tf)
pzmap(my_tf)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario:</b> Se observa una respuesta del tipo Butter. Como el filtro es de 3er orden se presentan 3 polos del lado izquierdo en el plano z con una distancia angular de $\frac{\pi}{3}$.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Simulación matemática desnormalizando los valores.
# </div></div>

# %%
from splane import pzmap, grpDelay, bodePlot
from scipy.signal import TransferFunction,bode
import matplotlib.pyplot as plt
import numpy as npy

## Simulación matemática.

C1 = 238e-12
C2 = 2.4e-9
C3 = 24e-9
R3 = 4700
G3 = 1 / R3
gm1 = 2.13e-6
gm2 = 21.3e-6
gm3 = 212.8e-6

c = (gm2 / C2) + (G3 / C3)
b = ((gm1*gm2) / (C1*C2)) + ((gm2*G3) / (C2*C3))
a = ((gm1*gm2*G3) / (C1*C2*C3))
d = ((gm1*gm2*gm3) / (C1*C2*C3))

num = [d]
den = [1,c,b,a]
 
my_tf = TransferFunction( num, den )

## Ploteo.
bodePlot(my_tf)
pzmap(my_tf)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario:</b> Desnormalizando los valores se obtiene la misma respuesta. Con los valores reales, el filtro responde a un diseño de Butter donde a $w_B$ = 2 * $\pi$ * 1KHz * $\epsilon^{-1/n}$ = 8922.12 Hz se encuentra el Q = $\frac{\sqrt{2}}{2}$ que en el gráfico corresponde a -3dB.
# </div>
