# %% [markdown]
# <img src="./logoutn.jpg" align="right" width="150" />
# #### Teoría de los Circuitos II - 2021
#
# # Tarea semanal 7
# ## Verificación utilizando herramientas de simulación.
# #### LAURIA JUAN

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Circuito a simular.
# </div></div>

# %% [markdown]
# <img src="./caps/circ1.jpg" align="center" width="800" />

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Respuesta en frecuencia.
# </div></div>

# %% [markdown]
# <img src="./caps/tran1.jpg" align="center" width="4000" />

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Simulación matemática utilizando valores normalizados.
# </div></div>

# %%
from scipy import signal
from splane import pzmap, grpDelay, bodePlot
from scipy.signal import TransferFunction,bode
import matplotlib.pyplot as plt
import numpy as npy


a = [1]
b = [1,2,2,1]

my_tf = TransferFunction(a,b)

## Ploteo.
bodePlot(my_tf)
pzmap(my_tf)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario:</b> Se logra verificar utilizando simulacion circuital y matemática la transferencia obtenida utilizando Matriz Admitancia Indefinida y el Método de la continuantes. La misma es $\frac{V2}{V1} =  \frac{1}{S^{3}+2 S^{2}+2 S+1}$
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b> Circuito equivalente aplicando transformación de Bruton.
# </div></div>

# %% [markdown]
# <img src="./caps/circ2.jpg" align="center" width="800" />

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b> Respuesta en frecuencia.
# </div></div>

# %% [markdown]
# <img src="./caps/tran2.jpg" align="center" width="4000" />
