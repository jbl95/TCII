# %% [markdown]
# <img src="./logoutn.jpg" align="right" width="150" />
# #### Teoría de los Circuitos II - 2021
#
# # Tarea semanal 12
# ## Simulación analítica y circuital.
# #### LAURIA JUAN

# %%
from scipy import signal
from splane import pzmap, grpDelay, bodePlot
from scipy.signal import TransferFunction,bode
import matplotlib.pyplot as plt
import numpy as npy

# %% [markdown]
# ## EJERCICIO #1

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Simulación matemática.
# </div></div>

# %% [markdown]
# Y11 = $\frac{I1}{V1}$ = $\frac{3$($^2 + 7/3)}{($^2 + 2)($^2 + 5)}$

# %%
# Y11 
a = [3,0,7,0]
b = [1,0,7,0,10]
my_tf = TransferFunction(a,b)
bodePlot(my_tf)
#pzmap(my_tf)
# Out:
# (1,
#  array([<AxesSubplot:title={'center':'Magnitude response'}, ylabel='Magnitude [dB]'>,
#         <AxesSubplot:title={'center':'Phase response'}, xlabel='Angular frequency [rad/sec]', ylabel='Phase [deg]'>],
#        dtype=object))

# %% [markdown]
# Y21 = $\frac{I2}{V1}$ = $\frac{$($^2 + 1)}{($^2 + 2)($^2 + 5)}$

# %%
# Y21
a = [1,0,1,0]
b = [1,0,7,0,10]
my_tf = TransferFunction(a,b)
bodePlot(my_tf)
#pzmap(my_tf)
# Out:
# (1,
#  array([<AxesSubplot:title={'center':'Magnitude response'}, ylabel='Magnitude [dB]'>,
#         <AxesSubplot:title={'center':'Phase response'}, xlabel='Angular frequency [rad/sec]', ylabel='Phase [deg]'>],
#        dtype=object))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Simulación circuital.
# </div></div>

# %% [markdown]
# <img src="./caps/circ.jpg" align="center" width="4000" />

# %% [markdown]
# <img src="./caps/y11.jpg" align="center" width="4000" />

# %% [markdown]
# <img src="./caps/y21.jpg" align="center" width="4000" />

# %% [markdown]
# ## EJERCICIO #2

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Simulación matemática.
# </div></div>

# %% [markdown]
# $\frac{V2}{V1}$ = $\frac{($ + 1)}{($ + 2)($ + 4)}$

# %%
# V2/V1
a = [1,1]
b = [1,6,8]
my_tf = TransferFunction(a,b)
bodePlot(my_tf)
#pzmap(my_tf)
# Out:
# (1,
#  array([<AxesSubplot:title={'center':'Magnitude response'}, ylabel='Magnitude [dB]'>,
#         <AxesSubplot:title={'center':'Phase response'}, xlabel='Angular frequency [rad/sec]', ylabel='Phase [deg]'>],
#        dtype=object))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Simulación circuital con Z11.
# </div></div>

# %% [markdown]
# <img src="./caps/circ2.jpg" align="center" width="4000" />

# %% [markdown]
# <img src="./caps/z11.jpg" align="center" width="4000" />

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Simulación circuital con Y22.
# </div></div>

# %% [markdown]
# <img src="./caps/circ3.jpg" align="center" width="4000" />

# %% [markdown]
# <img src="./caps/y22.jpg" align="center" width="4000" />
